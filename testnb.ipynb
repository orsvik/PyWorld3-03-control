# %% [markdown]
# # Test that notebooks work in the project

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Imports
import numpy as np
from pyworld3 import World3
from matplotlib import pyplot as plt
import pandas as pd
from tqdm import tqdm
import torch

# %%
# Test pollution
import pyworld3.pollution as po
from pyworld3.utils import plot_world_variables

pol = po.Pollution()
pol.set_pollution_table_functions()
pol.init_pollution_variables()
pol.init_pollution_constants()
pol.set_pollution_delay_functions()
pol.init_exogenous_inputs()
pol.run_pollution()
ef = np.array(pol.ef)
plot_world_variables(time=pol.time, var_data=[ef], var_names=['EF'], var_lims=[[0, 15]])
