# %% [markdown]
# # Test that notebooks work in the project

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Imports
import numpy as np
from pyworld3 import World3
from matplotlib import pyplot as plt
import pandas as pd
from tqdm import tqdm
import torch

# %%
# Test pollution
import pyworld3.pollution as po
from pyworld3.utils import plot_world_variables

pol = po.Pollution()
pol.set_pollution_table_functions()
pol.init_pollution_variables()
pol.init_pollution_constants()
pol.set_pollution_delay_functions()
pol.init_exogenous_inputs()
pol.run_pollution()
plot_world_variables(time=np.arange(len(pol.ef)), var_data=[pol.ef], var_names=['EF'], var_lims=[100])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 12
#      10 pol.init_exogenous_inputs()
#      11 pol.run_pollution()
# ---> 12 plot_world_variables(var_data=[pol.ef], var_names=['EF'])
#
# TypeError: plot_world_variables() missing 2 required positional arguments: 'time' and 'var_lims'
